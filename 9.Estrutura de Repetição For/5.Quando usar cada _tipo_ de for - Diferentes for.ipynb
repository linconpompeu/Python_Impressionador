# %%
produtos = ["iphone", "ipad", "airpod", "macbook"]
precos = [7000, 10000, 2500, 14000]

# %% [markdown]
# ### For item in lista

# %%
# preco com imposto

for preco in precos:
    print(preco * 1.1)
# Out:
# 7700.000000000001
# 11000.0
# 2750.0
# 15400.000000000002

# %% [markdown]
# ### For i in range

# %%
# preco de cada produto

for i in range(len(precos)):
    produto = produtos[i]
    preco = precos[i]
    print("O item {} tem o preco de R$ {:.2f}".format(produto, preco))
# Out:
# O item iphone tem o preco de R$ 7000.00
# O item ipad tem o preco de R$ 10000.00
# O item airpod tem o preco de R$ 2500.00
# O item macbook tem o preco de R$ 14000.00

# %% [markdown]
# ### For item in lista com enumerate

# %%
# preco de cada produto com imposto
for i, preco in enumerate(precos):
    produto = produtos[i]
    print(produto, preco)
# Out:
# iphone 7000
# ipad 10000
# airpod 2500
# macbook 14000
