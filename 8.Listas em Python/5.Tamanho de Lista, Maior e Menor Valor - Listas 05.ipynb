# %% [markdown]
# # Algumas Funções Básicas de Lista
#
# ## Tamanho da Lista
#
# tamanho = len(lista)

# %%
produtos = ['apple tv', 'mac', 'iphone x', 'IPad', 'apple watch', 'mac book', 'airpods']

# %% [markdown]
# - Quantos produtos temos a venda?

# %%
tamanho = len(produtos)
print('Temos {} produtos'.format(tamanho))
# Out:
# Temos 7 produtos

# %% [markdown]
# ## Maior e Menor Valor
#
# maior = max(lista)
#
# menor = min(lista)

# %%
vendas = [1000, 1500, 15000, 270, 900, 100, 1200]

# %% [markdown]
# - Qual o item mais vendido?
# - Qual o item menos vendido?

# %%
mais_vendido = max(vendas)
menos_vendido = min(vendas)
i_mais_vendido = vendas.index(mais_vendido)
i_menos_vendido = vendas.index(menos_vendido)
print('O item mais vendido foi o {}, com uma quantidade de {}, e o menos vendido foi o {}, com uma quantidade de {}.'.format(produtos[i_mais_vendido], mais_vendido, produtos[i_menos_vendido], menos_vendido))
# Out:
# O item mais vendido foi o iphone x, com uma quantidade de 15000, e o menos vendido foi o mac book, com uma quantidade de 100.
