# %% [markdown]
# # Python e API
#
# ### O que é uma API?
#
# - É um conjunto de códigos para usar um serviço/site/aplicativo específico. Cada site/ferramenta tem sua própria API. É importante que você saiba ler as APIs que precisar para saber usar
#
# - Um dos padrões mais comuns em API é pegar informações em formato json, uma espécie de dicionário que precisa ser tratada no Python para podermos analisar
#
# - As possibilidades de API são infinitas, vamos fazer 2 exemplos aqui: Cotação de Moedas e Envio de SMS.
#
# - Sites como Google, Youtube, Facebook, Twitter, ArcGis e praticamente qualquer ferramenta/site grande tem uma API.
#
# ### O que precisamos:
#
# - Quase sempre você precisa de uma conta para consumir uma API. Algumas APIs são abertas, como a https://docs.awesomeapi.com.br/api-de-moedas , mas em muitos casos (como veremos no caso do SMS) vamos precisar ter uma conta ativa para consumir a API
#
# - A Documentação da API (ou exemplos da internet) é a chave para conseguir usar uma API

# %% [markdown]
# #### Pegar a Cotação Atual de Todas as Moedas

# %%
import requests
import json

cotacoes = requests.get('https://economia.awesomeapi.com.br/json/all')
cotacoes_dic = cotacoes.json()

display(cotacoes_dic)
# Out:
# {'USD': {'code': 'USD',
#   'codein': 'BRL',
#   'name': 'Dólar Americano/Real Brasileiro',
#   'high': '5.1612',
#   'low': '5.1266',
#   'varBid': '0.0099',
#   'pctChange': '0.192479',
#   'bid': '5.1534',
#   'ask': '5.1538',
#   'timestamp': '1789507813',
#   'create_date': '2026-09-15 18:30:13'},
#  'USDT': {'code': 'USD',
#   'codein': 'BRLT',
#   'name': 'Dólar Americano/Real Brasileiro Turismo',
#   'high': '5.12205',
#   'low': '5.08771',
#   'varBid': '0.00983',
#   'pctChange': '0.19258',
#   'bid': '5.11431',
#   'ask': '5.51448',
#   'timestamp': '1789507815',
#   'create_date': '2026-09-15 18:30:15'},
#  'CAD': {'code': 'CAD',
#   'codein': 'BRL',
#   'name': 'Dólar Canadense/Real Brasileiro',
#   'high': '3.70371',
#   'low': '3.67263',
#   'varBid': '-0.003366',
#   'pctChange': '-0.091094',
#   'bid': '3.69164',
#   'ask': '3.70042',
#   'timestamp': '1789510762',
#   'create_date': '2026-09-15 19:19:22'},
#  'GBP': {'code': 'GBP',
#   'codein': 'BRL',
#   'name': 'Libra Esterlina/Real Brasileiro',
#   'high': '6.95835',
#   'low': '6.90608',
#   'varBid': '-0.005344',
#   'pctChange': '-0.077039',
#   'bid': '6.93153',
#   'ask': '6.93557',
#   'timestamp': '1789510770',
#   'create_date': '2026-09-15 19:19:30'},
#  'ARS': {'code': 'ARS',
#   'codein': 'BRL',
#   'name': 'Peso Argentino/Real Brasileiro',
#   'high': '0.00342411',
#   'low': '0.00339487',
#   'varBid': '0.000007',
#   'pctChange': '0.191006',
#   'bid': '0.00341479',
#   'ask': '0.00341481',
#   'timestamp': '1789510917',
#   'create_date': '2026-09-15 19:21:57'},
#  'BTC': {'code': 'BTC',
#   'codein': 'BRL',
#   'name': 'Bitcoin/Real Brasileiro',
#   'high': '406032',
#   'low': '387000',
#   'varBid': '-16855',
#   'pctChange': '-4.154',
#   'bid': '388866',
#   'ask': '388867',
#   'timestamp': '1789510967',
#   'create_date': '2026-09-15 19:22:47'},
#  'LTC': {'code': 'LTC',
#   'codein': 'BRL',
#   'name': 'Litecoin/Real Brasileiro',
#   'high': '275.8',
#   'low': '262.2',
#   'varBid': '-12.4',
#   'pctChange': '-4.503',
#   'bid': '263',
#   'ask': '263.2',
#   'timestamp': '1789510967',
#   'create_date': '2026-09-15 19:22:47'},
#  'EUR': {'code': 'EUR',
#   'codein': 'BRL',
#   'name': 'Euro/Real Brasileiro',
#   'high': '5.9397',
#   'low': '5.9225',
#   'varBid': '0.0028',
#   'pctChange': '0.047171',
#   'bid': '5.9383',
#   'ask': '5.9404',
#   'timestamp': '1789510915',
#   'create_date': '2026-09-15 19:21:55'},
#  'JPY': {'code': 'JPY',
#   'codein': 'BRL',
#   'name': 'Iene Japonês/Real Brasileiro',
#   'high': '0.03327774',
#   'low': '0.03303411',
#   'varBid': '-0.000116',
#   'pctChange': '-0.348307',
#   'bid': '0.03316183',
#   'ask': '0.03318117',
#   'timestamp': '1789510770',
#   'create_date': '2026-09-15 19:19:30'},
#  'CHF': {'code': 'CHF',
#   'codein': 'BRL',
#   'name': 'Franco Suíço/Real Brasileiro',
#   'high': '6.29104',
#   'low': '6.25065',
#   'varBid': '-0.007683',
#   'pctChange': '-0.122262',
#   'bid': '6.27647',
#   'ask': '6.29139',
#   'timestamp': '1789510762',
#   'create_date': '2026-09-15 19:19:22'},
#  'AUD': {'code': 'AUD',
#   'codein': 'BRL',
#   'name': 'Dólar Australiano/Real Brasileiro',
#   'high': '3.67411',
#   'low': '3.64615',
#   'varBid': '-0.00137',
#   'pctChange': '-0.037372',
#   'bid': '3.66457',
#   'ask': '3.67329',
#   'timestamp': '1789510762',
#   'create_date': '2026-09-15 19:19:22'},
#  'CNY': {'code': 'CNY',
#   'codein': 'BRL',
#   'name': 'Yuan Chinês/Real Brasileiro',
#   'high': '0.76850641',
#   'low': '0.76673573',
#   'varBid': '0.001145',
#   'pctChange': '0.149312',
#   'bid': '0.76788056',
#   'ask': '0.76788295',
#   'timestamp': '1789507820',
#   'create_date': '2026-09-15 18:30:20'},
#  'ILS': {'code': 'ILS',
#   'codein': 'BRL',
#   'name': 'Novo Shekel Israelense/Real Brasileiro',
#   'high': '1.692',
#   'low': '1.676',
#   'varBid': '0.005',
#   'pctChange': '0.296911',
#   'bid': '1.689',
#   'ask': '1.699',
#   'timestamp': '1789510613',
#   'create_date': '2026-09-15 19:16:53'},
#  'ETH': {'code': 'ETH',
#   'codein': 'BRL',
#   'name': 'Ethereum/Real Brasileiro',
#   'high': '13141.62',
#   'low': '12175.88',
#   'varBid': '-809.56',
#   'pctChange': '-6.164',
#   'bid': '12325.07',
#   'ask': '12326.09',
#   'timestamp': '1789510967',
#   'create_date': '2026-09-15 19:22:47'},
#  'XRP': {'code': 'XRP',
#   'codein': 'BRL',
#   'name': 'XRP/Real Brasileiro',
#   'high': '7.511',
#   'low': '6.536',
#   'varBid': '-0.837',
#   'pctChange': '-11.247',
#   'bid': '6.608',
#   'ask': '6.615',
#   'timestamp': '1789510967',
#   'create_date': '2026-09-15 19:22:47'},
#  'DOGE': {'code': 'DOGE',
#   'codein': 'BRL',
#   'name': 'Dogecoin/Real Brasileiro',
#   'high': '0.4349',
#   'low': '0.4052',
#   'varBid': '-0.0238',
#   'pctChange': '-5.474',
#   'bid': '0.4109',
#   'ask': '0.411',
#   'timestamp': '1789510967',
#   'create_date': '2026-09-15 19:22:47'}}

# %% [markdown]
# #### Qual foi a última cotação do Dólar, do Euro e do BitCoin? (Sua resposta vai dar diferente do gabarito, porque estamos rodando o código em momentos diferentes, mas o seu código deve ser o mesmo/parecido)

# %% [markdown]
# #### Pegar a cotação dos últimos 30 dias do dólar (Sua resposta vai dar diferente do gabarito, porque estamos rodando o código em momentos diferentes, mas o seu código deve ser o mesmo/parecido)

# %% [markdown]
# #### Pegar as cotações do BitCoin de Jan/20 a Out/20

# %% [markdown]
# #### Gráfico com as cotações do BitCoin
