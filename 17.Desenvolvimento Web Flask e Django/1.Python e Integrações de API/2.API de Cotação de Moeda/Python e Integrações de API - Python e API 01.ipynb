# %% [markdown]
# # Python e API
#
# ### O que é uma API?
#
# - É um conjunto de códigos para usar um serviço/site/aplicativo específico. Cada site/ferramenta tem sua própria API. É importante que você saiba ler as APIs que precisar para saber usar
#
# - Um dos padrões mais comuns em API é pegar informações em formato json, uma espécie de dicionário que precisa ser tratada no Python para podermos analisar
#
# - As possibilidades de API são infinitas, vamos fazer 2 exemplos aqui: Cotação de Moedas e Envio de SMS.
#
# - Sites como Google, Youtube, Facebook, Twitter, ArcGis e praticamente qualquer ferramenta/site grande tem uma API.
#
# ### O que precisamos:
#
# - Quase sempre você precisa de uma conta para consumir uma API. Algumas APIs são abertas, como a https://docs.awesomeapi.com.br/api-de-moedas , mas em muitos casos (como veremos no caso do SMS) vamos precisar ter uma conta ativa para consumir a API
#
# - A Documentação da API (ou exemplos da internet) é a chave para conseguir usar uma API

# %% [markdown]
# #### Pegar a Cotação Atual de Todas as Moedas

# %%
import requests
import json

cotacoes = requests.get('https://economia.awesomeapi.com.br/json/all')
cotacoes_dic = cotacoes.json()

display(cotacoes_dic)
# Out:
# {'USD': {'code': 'USD',
#   'codein': 'BRL',
#   'name': 'Dólar Americano/Real Brasileiro',
#   'high': '5.1294',
#   'low': '5.1245',
#   'varBid': '0.0036',
#   'pctChange': '0.070255',
#   'bid': '5.1281',
#   'ask': '5.1293',
#   'timestamp': '1789731572',
#   'create_date': '2026-09-18 08:39:32'},
#  'USDT': {'code': 'USD',
#   'codein': 'BRLT',
#   'name': 'Dólar Americano/Real Brasileiro Turismo',
#   'high': '5.09049',
#   'low': '5.08563',
#   'varBid': '0.00357',
#   'pctChange': '0.070199',
#   'bid': '5.0892',
#   'ask': '5.48826',
#   'timestamp': '1789731572',
#   'create_date': '2026-09-18 08:39:32'},
#  'CAD': {'code': 'CAD',
#   'codein': 'BRL',
#   'name': 'Dólar Canadense/Real Brasileiro',
#   'high': '3.6639',
#   'low': '3.65457',
#   'varBid': '-0.006444',
#   'pctChange': '-0.175875',
#   'bid': '3.65746',
#   'ask': '3.66607',
#   'timestamp': '1789732352',
#   'create_date': '2026-09-18 08:52:32'},
#  'GBP': {'code': 'GBP',
#   'codein': 'BRL',
#   'name': 'Libra Esterlina/Real Brasileiro',
#   'high': '6.85968',
#   'low': '6.83527',
#   'varBid': '0.000403',
#   'pctChange': '0.00589',
#   'bid': '6.84408',
#   'ask': '6.84809',
#   'timestamp': '1789732624',
#   'create_date': '2026-09-18 08:57:04'},
#  'ARS': {'code': 'ARS',
#   'codein': 'BRL',
#   'name': 'Peso Argentino/Real Brasileiro',
#   'high': '0.00339952',
#   'low': '0.00338957',
#   'varBid': '0.000002',
#   'pctChange': '0.071876',
#   'bid': '0.00339722',
#   'ask': '0.00339724',
#   'timestamp': '1789732673',
#   'create_date': '2026-09-18 08:57:53'},
#  'BTC': {'code': 'BTC',
#   'codein': 'BRL',
#   'name': 'Bitcoin/Real Brasileiro',
#   'high': '402984',
#   'low': '392479',
#   'varBid': '6541',
#   'pctChange': '1.658',
#   'bid': '401075',
#   'ask': '401076',
#   'timestamp': '1789732718',
#   'create_date': '2026-09-18 08:58:38'},
#  'LTC': {'code': 'LTC',
#   'codein': 'BRL',
#   'name': 'Litecoin/Real Brasileiro',
#   'high': '287.6',
#   'low': '271.9',
#   'varBid': '11',
#   'pctChange': '4.04',
#   'bid': '283.3',
#   'ask': '283.6',
#   'timestamp': '1789732717',
#   'create_date': '2026-09-18 08:58:37'},
#  'EUR': {'code': 'EUR',
#   'codein': 'BRL',
#   'name': 'Euro/Real Brasileiro',
#   'high': '5.9104',
#   'low': '5.8767',
#   'varBid': '-0.0096',
#   'pctChange': '-0.163092',
#   'bid': '5.8767',
#   'ask': '5.8787',
#   'timestamp': '1789732438',
#   'create_date': '2026-09-18 08:53:58'},
#  'JPY': {'code': 'JPY',
#   'codein': 'BRL',
#   'name': 'Iene Japonês/Real Brasileiro',
#   'high': '0.03282951',
#   'low': '0.03241073',
#   'varBid': '-0.000327',
#   'pctChange': '-0.996896',
#   'bid': '0.03248655',
#   'ask': '0.03250556',
#   'timestamp': '1789732624',
#   'create_date': '2026-09-18 08:57:04'},
#  'CHF': {'code': 'CHF',
#   'codein': 'BRL',
#   'name': 'Franco Suíço/Real Brasileiro',
#   'high': '6.21859',
#   'low': '6.20291',
#   'varBid': '-0.007173',
#   'pctChange': '-0.115443',
#   'bid': '6.20646',
#   'ask': '6.22107',
#   'timestamp': '1789732352',
#   'create_date': '2026-09-18 08:52:32'},
#  'AUD': {'code': 'AUD',
#   'codein': 'BRL',
#   'name': 'Dólar Australiano/Real Brasileiro',
#   'high': '3.65296',
#   'low': '3.63999',
#   'varBid': '0.002418',
#   'pctChange': '0.066297',
#   'bid': '3.64957',
#   'ask': '3.65816',
#   'timestamp': '1789732352',
#   'create_date': '2026-09-18 08:52:32'},
#  'CNY': {'code': 'CNY',
#   'codein': 'BRL',
#   'name': 'Yuan Chinês/Real Brasileiro',
#   'high': '0.76473745',
#   'low': '0.76400691',
#   'varBid': '0.000731',
#   'pctChange': '0.09562',
#   'bid': '0.76473745',
#   'ask': '0.76474798',
#   'timestamp': '1789721628',
#   'create_date': '2026-09-18 05:53:48'},
#  'ILS': {'code': 'ILS',
#   'codein': 'BRL',
#   'name': 'Novo Shekel Israelense/Real Brasileiro',
#   'high': '1.693746',
#   'low': '1.684',
#   'varBid': '-0.002',
#   'pctChange': '-0.118556',
#   'bid': '1.685',
#   'ask': '1.695',
#   'timestamp': '1789732307',
#   'create_date': '2026-09-18 08:51:47'},
#  'ETH': {'code': 'ETH',
#   'codein': 'BRL',
#   'name': 'Ethereum/Real Brasileiro',
#   'high': '12947.83',
#   'low': '12539.17',
#   'varBid': '289.67',
#   'pctChange': '2.299',
#   'bid': '12880.14',
#   'ask': '12886.97',
#   'timestamp': '1789732713',
#   'create_date': '2026-09-18 08:58:33'},
#  'XRP': {'code': 'XRP',
#   'codein': 'BRL',
#   'name': 'XRP/Real Brasileiro',
#   'high': '6.885',
#   'low': '6.626',
#   'varBid': '0.102',
#   'pctChange': '1.522',
#   'bid': '6.797',
#   'ask': '6.801',
#   'timestamp': '1789732703',
#   'create_date': '2026-09-18 08:58:23'},
#  'DOGE': {'code': 'DOGE',
#   'codein': 'BRL',
#   'name': 'Dogecoin/Real Brasileiro',
#   'high': '0.4467',
#   'low': '0.4161',
#   'varBid': '0.0203',
#   'pctChange': '4.854',
#   'bid': '0.4382',
#   'ask': '0.4383',
#   'timestamp': '1789732693',
#   'create_date': '2026-09-18 08:58:13'}}

# %% [markdown]
# #### Qual foi a última cotação do Dólar, do Euro e do BitCoin? (Sua resposta vai dar diferente do gabarito, porque estamos rodando o código em momentos diferentes, mas o seu código deve ser o mesmo/parecido)

# %%
display('Dolar: {}'.format(cotacoes_dic['USD']['bid']))
display('Euro: {}'.format(cotacoes_dic['EUR']['bid']))
display('BITCOIN: {}'.format(cotacoes_dic['BTC']['bid']))
# Out:
# 'Dolar: 5.1281'
# 'Euro: 5.8767'
# 'BITCOIN: 401075'

# %% [markdown]
# #### Pegar a cotação dos últimos 30 dias do dólar (Sua resposta vai dar diferente do gabarito, porque estamos rodando o código em momentos diferentes, mas o seu código deve ser o mesmo/parecido)

# %%
cotacao_dolar_30d = requests.get('https://economia.awesomeapi.com.br/json/daily/USD-BRL/30')
cotacao_dolar_30d_dic = cotacao_dolar_30d.json()
#display(cotacao_dolar_30d_dic[0]['bid'])
lista_cotacao_dolar_30d = []
for i in range(len(cotacao_dolar_30d_dic)):
    lista_cotacao_dolar_30d.append(cotacao_dolar_30d_dic[i]['bid'])
display(lista_cotacao_dolar_30d)
# Out:
# ['5.1301',
#  '5.1245',
#  '5.1499',
#  '5.1529',
#  '5.1435',
#  '5.1262',
#  '5.1033',
#  '5.1048',
#  '5.0867',
#  '5.1259',
#  '5.1249',
#  '5.0998',
#  '5.0932',
#  '5.1539',
#  '5.1837',
#  '5.185',
#  '5.1621',
#  '5.1465',
#  '5.1472',
#  '5.1572',
#  '5.1364',
#  '5.138',
#  '5.1929',
#  '5.1788',
#  '5.2133',
#  '5.2042',
#  '5.21917',
#  '5.2225',
#  '5.1795',
#  '5.1904']

# %%
cotacao_dolar_30d = requests.get('https://economia.awesomeapi.com.br/json/daily/USD-BRL/30')
cotacao_dolar_30d_dic = cotacao_dolar_30d.json()
#display(cotacao_dolar_30d_dic[0]['bid'])
lista_cotacao_dolar_30d = [float(item['bid']) for item in cotacao_dolar_30d_dic]

# %% [markdown]
# #### Pegar as cotações do BitCoin de Jan/20 a Out/20

# %%
cotacao_bitcoin_jan20_a_out20 = requests.get(
    'https://economia.awesomeapi.com.br/json/daily/BTC-BRL/200?start_date=20200101&end_date=20200930')

cotacao_bitcoin_jan20_a_out20_dic = cotacao_bitcoin_jan20_a_out20.json()
lista_cotacao_bitcoin_jan20_a_out20 = [float(item['bid']) for item in cotacao_bitcoin_jan20_a_out20_dic]
lista_cotacao_bitcoin_jan20_a_out20.reverse()
display(lista_cotacao_bitcoin_jan20_a_out20)
display(len(lista_cotacao_bitcoin_jan20_a_out20))
# Out:
# [28150.0,
#  27050.0,
#  27935.0,
#  25715.6,
#  27100.0,
#  27669.4,
#  32011.0,
#  31820.1,
#  32084.3,
#  30879.8,
#  32605.1,
#  34155.0,
#  33801.0,
#  33890.9,
#  33050.0,
#  32142.5,
#  31000.0,
#  33000.1,
#  32577.9,
#  33510.6,
#  34550.7,
#  35600.0,
#  35601.3,
#  35320.4,
#  37655.2,
#  37250.0,
#  37720.1,
#  37255.2,
#  36007.0,
#  36360.0,
#  35800.0,
#  35750.0,
#  35150.0,
#  37025.0,
#  36836.7,
#  37415.0,
#  37158.0,
#  36652.1,
#  36800.0,
#  38000.1,
#  40050.0,
#  41050.0,
#  41212.0,
#  41715.0,
#  43392.0,
#  43070.0,
#  46424.7,
#  46610.0,
#  47626.0,
#  47900.0,
#  48553.0,
#  48852.0,
#  49700.0,
#  52500.0,
#  57700.0,
#  52609.1,
#  52499.0,
#  49225.0,
#  49700.0,
#  51488.8,
#  54450.0,
#  56208.0,
#  53609.0,
#  54207.4,
#  55300.0,
#  55651.1,
#  55760.8,
#  54831.8,
#  51440.0,
#  51400.0,
#  51600.0,
#  49560.0,
#  49735.0,
#  47625.1,
#  49000.2,
#  51700.3,
#  50650.0,
#  51500.0,
#  50865.1,
#  53600.0,
#  54001.0,
#  49500.4,
#  50400.6,
#  48820.6,
#  49133.5,
#  48096.8,
#  48201.0,
#  49350.0,
#  47000.0,
#  48100.1,
#  47788.9,
#  47750.0,
#  48501.4,
#  49679.0,
#  49290.6,
#  50405.0,
#  49700.0,
#  49750.0,
#  49782.0,
#  50710.0,
#  49759.1,
#  49800.0,
#  49755.0,
#  49915.1,
#  49678.2,
#  49746.8,
#  49840.0,
#  49960.0,
#  49800.0,
#  49208.8,
#  48815.5,
#  48993.1,
#  48850.0,
#  49890.0,
#  49900.1,
#  50360.1,
#  49890.0,
#  49905.9,
#  49750.0,
#  49920.0,
#  50041.3,
#  50073.4,
#  49868.0,
#  49320.0,
#  49702.1,
#  49651.8,
#  49680.0,
#  49516.5,
#  49143.0,
#  49321.0,
#  49850.0,
#  49951.1,
#  50400.2,
#  50402.0,
#  55300.0,
#  56161.0,
#  57490.0,
#  57330.0,
#  58950.0,
#  61298.1,
#  58296.3,
#  59800.0,
#  59951.0,
#  61902.2,
#  63302.0,
#  63140.0,
#  63715.0,
#  63700.0,
#  65303.8,
#  62300.0,
#  63120.0,
#  63210.3,
#  63905.0,
#  64280.0,
#  64270.3,
#  67501.0,
#  66453.3,
#  65800.0,
#  66655.0,
#  65657.4,
#  66112.0,
#  66100.0,
#  66360.9,
#  63606.0,
#  64655.2,
#  63599.9,
#  63016.2,
#  62700.0,
#  63350.9,
#  64200.0,
#  64900.0,
#  61939.0,
#  55336.6,
#  56500.0,
#  54555.7,
#  55550.3,
#  55102.2,
#  54348.3,
#  55059.1,
#  55511.0,
#  55821.2,
#  55856.7,
#  55566.0,
#  56908.9,
#  57700.0,
#  58250.0,
#  57807.2,
#  59285.0,
#  59750.0,
#  59100.0,
#  57050.6,
#  57880.5,
#  57884.0,
#  59501.1,
#  59845.0,
#  59720.5,
#  59638.4,
#  60600.1,
#  60995.0,
#  60950.1]
# 200

# %% [markdown]
# #### Gráfico com as cotações do BitCoin

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.plot(lista_cotacao_bitcoin_jan20_a_out20)
